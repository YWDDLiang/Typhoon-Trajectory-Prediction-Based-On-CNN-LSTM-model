# %%
import cdsapi
# Libraries for working with multidimensional arrays
import numpy as np
import xarray as xr

# Libraries for plotting and visualising data
import matplotlib.path as mpath
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import cartopy.feature as cfeature

# Disable warnings for data download via API
import urllib3 
urllib3.disable_warnings()

# %%
URL = 'https://cds-beta.climate.copernicus.eu/api'
KEY = '0d9a33a4-3541-4c92-ac8e-b8314c2ee0f4'
DATADIR = '/home/dl392/data/yiwei/typhoon/EAR5/'
import cdsapi
 
dataset = "reanalysis-era5-single-levels"
request = {
    "product_type": ["reanalysis"],
    "variable": [
        "sea_surface_temperature",
        "surface_pressure"
    ],
    "year": ["2023"],
    "month": ["04"],
    "day": ["11"],
    "time": [
        "00:00", "06:00", "12:00",
        "18:00"
    ],
    "data_format": "grib",
    "download_format": "unarchived",
    "area": [15, 100, 10, 115]
}
URL = 'https://cds-beta.climate.copernicus.eu/api'
KEY = '0d9a33a4-3541-4c92-ac8e-b8314c2ee0f4'
DATADIR = '/home/dl392/data/yiwei/typhoon/EAR5/'
dataset = "reanalysis-era5-single-levels"
client = cdsapi.Client(url=URL, key=KEY)
client.retrieve(dataset, request,f'{DATADIR}temp.grib')
# Out:
# 2024-11-15 06:32:38,599 INFO [2024-09-28T00:00:00] **Welcome to the New Climate Data Store (CDS)!** This new system is in its early days of full operations and still undergoing enhancements and fine tuning. Some disruptions are to be expected. Your
# [feedback](https://jira.ecmwf.int/plugins/servlet/desk/portal/1/create/202) is key to improve the user experience on the new CDS for the benefit of everyone. Thank you.
# 2024-11-15 06:32:38,601 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2024-11-15 06:32:38,602 INFO [2024-09-16T00:00:00] Remember that you need to have an ECMWF account to use the new CDS. **Your old CDS credentials will not work in new CDS!**
# ...

# %%
ds = xr.open_dataset("/home/dl392/data/yiwei/typhoon/EAR5/temp.grib",engine="cfgrib")

# %%
ds
# Out:
# <xarray.Dataset> Size: 42kB
# Dimensions:     (time: 4, latitude: 21, longitude: 61)
# Coordinates:
#     number      int64 8B ...
#   * time        (time) datetime64[ns] 32B 2023-04-11 ... 2023-04-11T18:00:00
#     step        timedelta64[ns] 8B ...
#     surface     float64 8B ...
#   * latitude    (latitude) float64 168B 15.0 14.75 14.5 ... 10.5 10.25 10.0
#   * longitude   (longitude) float64 488B 100.0 100.2 100.5 ... 114.5 114.8 115.0
#     valid_time  (time) datetime64[ns] 32B ...
# Data variables:
#     sst         (time, latitude, longitude) float32 20kB ...
#     sp          (time, latitude, longitude) float32 20kB ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
# ...

# %%
latitude = 13.7 
longitude = 126.5

# 选择指定经纬度的 sea_surface_temperature 和 surface_pressure
sst = ds['sst'].sel(time='2023-04-11T00:00:00',latitude=latitude, longitude=longitude, method="nearest")
sp = ds['sp'].sel(time='2023-04-11T06',latitude=latitude, longitude=longitude, method="nearest")

# 打印或检查数据
print("Sea Surface Temperature at (13.7, 126.5):", sst.values)
print("Surface Pressure at (13.7, 126.5):", sp.values)
# Out:
# Sea Surface Temperature at (13.7, 126.5): 301.5332
# Surface Pressure at (13.7, 126.5): 101205.56

# %%
time = ConvertedDateTime
sst = ds['sst'].sel(time=time,latitude=latitude, longitude=longitude, method="nearest")
sp = ds['sp'].sel(time=time,latitude=latitude, longitude=longitude, method="nearest")
